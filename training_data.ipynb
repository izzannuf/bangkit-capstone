# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head(50)
# Out:
#     distance(meters)  rating_overall  rating_count  would_go
# 0               1824             4.3            30      True
# 1                409             4.9            30      True
# 2               4506             1.2            41     False
# 3               4012             1.9            12     False
# 4               3657             4.3            48      True
# 5               2286             2.1            18     False
# 6               1679             1.6            20     False
# 7               8935             2.4            18     False
# 8               1424             4.6            41      True
# 9               9674             1.9             3     False
# 10              6912             4.9            49     False
# 11               520             4.0             5      True
# 12               488             3.3            41     False
# 13              1535             0.8            36     False
# ...
